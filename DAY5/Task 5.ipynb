# %%
import pandas as pd
import time
from mlxtend.frequent_patterns import apriori, fpgrowth, association_rules

# %%
# Load the dataset (assumes it's already cleaned as in your previous code)
df = pd.read_excel("Online Retail.xlsx")

# %%
# Clean and filter for France
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

france = (
    df[df['Country'] == "France"]
        .groupby(['InvoiceNo', 'Description'])['Quantity']
        .sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')
)
france_encoded = france > 0

# %%
# Apriori Timing
start_apriori = time.time()
frequent_apriori = apriori(france_encoded, min_support=0.01, use_colnames=True)
end_apriori = time.time()

rules_apriori = association_rules(frequent_apriori, metric="lift", min_threshold=1.0)
top_apriori = rules_apriori.sort_values(by='lift', ascending=False).head(10)

# %%
# FP-Growth Timing
start_fpgrowth = time.time()
frequent_fpgrowth = fpgrowth(france_encoded, min_support=0.01, use_colnames=True)
end_fpgrowth = time.time()

rules_fpgrowth = association_rules(frequent_fpgrowth, metric="lift", min_threshold=1.0)
top_fpgrowth = rules_fpgrowth.sort_values(by='lift', ascending=False).head(10)

# %%
# Print Comparison
print("Apriori Time: {:.2f} seconds".format(end_apriori - start_apriori))
print("FP-Growth Time: {:.2f} seconds".format(end_fpgrowth - start_fpgrowth))
print("\nTop 10 Rules from Apriori:")
print(top_apriori[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
print("\nTop 10 Rules from FP-Growth:")
top_fpgrowth[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
# Out:
# Apriori Time: 23.49 seconds
# FP-Growth Time: 132.05 seconds
#
# Top 10 Rules from Apriori:
#                                                antecedents  \
# 1349992  (DOLLY GIRL CHILDRENS CUP, ALARM CLOCK BAKELIK...
# 1349989  (DOLLY GIRL CHILDRENS CUP, LUNCH BOX I LOVE LO...
# 1349988  (LUNCH BOX WITH CUTLERY RETROSPOT, DOLLY GIRL ...
# 917649   (TREASURE TIN GYMKHANA DESIGN, ROUND SNACK BOX...
# 917641   (TREASURE TIN GYMKHANA DESIGN, PLASTERS IN TIN...
# 917632   (TREASURE TIN GYMKHANA DESIGN, PLASTERS IN TIN...
# 917631   (TREASURE TIN GYMKHANA DESIGN, ROUND SNACK BOX...
# 702049   (LUNCH BAG SPACEBOY DESIGN, SET/6 RED SPOTTY P...
# 1349959   (SKULL LUNCH BOX WITH CUTLERY, JUMBO BAG APPLES)
# 1349946  (ALARM CLOCK BAKELIKE PINK, CHILDRENS CUTLERY ...
#
#                                                consequents   support  \
# 1349992  (ALARM CLOCK BAKELIKE RED, SKULL LUNCH BOX WIT...  0.010204
# 1349989  (ALARM CLOCK BAKELIKE RED, SKULL LUNCH BOX WIT...  0.010204
# 1349988  (ALARM CLOCK BAKELIKE RED, SKULL LUNCH BOX WIT...  0.010204
# 917649   (MAGNETS PACK OF 4 SWALLOWS, PLASTERS IN TIN C...  0.010204
# 917641   (MAGNETS PACK OF 4 SWALLOWS, PLASTERS IN TIN W...  0.010204
# 917632   (MAGNETS PACK OF 4 SWALLOWS, ROUND SNACK BOXES...  0.010204
# 917631   (MAGNETS PACK OF 4 SWALLOWS, LUNCH BOX I LOVE ...  0.010204
# 702049   (RED RETROSPOT CHILDRENS UMBRELLA, ALARM CLOCK...  0.010204
# 1349959  (ALARM CLOCK BAKELIKE RED, LUNCH BAG APPLE DES...  0.010204
# 1349946  (ALARM CLOCK BAKELIKE RED, SKULL LUNCH BOX WIT...  0.010204
#
#          confidence  lift
# 1349992         1.0  98.0
# 1349989         1.0  98.0
# 1349988         1.0  98.0
# 917649          1.0  98.0
# 917641          1.0  98.0
# 917632          1.0  98.0
# 917631          1.0  98.0
# 702049          1.0  98.0
# 1349959         1.0  98.0
# 1349946         1.0  98.0
#
# Top 10 Rules from FP-Growth:
#                                               antecedents  \
# 327102  (ALARM CLOCK BAKELIKE RED, LUNCH BAG SPACEBOY ...
# 327089  (ALARM CLOCK BAKELIKE RED, SKULL LUNCH BOX WIT...
# 327087  (ALARM CLOCK BAKELIKE RED, SKULL LUNCH BOX WIT...
# 327086  (ALARM CLOCK BAKELIKE RED, SKULL LUNCH BOX WIT...
# 327085  (ALARM CLOCK BAKELIKE RED, SKULL LUNCH BOX WIT...
# 327084  (ALARM CLOCK BAKELIKE RED, SKULL LUNCH BOX WIT...
# 327164  (SKULL LUNCH BOX WITH CUTLERY, ROUND SNACK BOX...
# 327163  (SKULL LUNCH BOX WITH CUTLERY, ROUND SNACK BOX...
# 327162  (SKULL LUNCH BOX WITH CUTLERY, ROUND SNACK BOX...
# 327183  (LUNCH BAG SPACEBOY DESIGN, LUNCH BOX WITH CUT...
#
#                                               consequents   support  \
# 327102  (ALARM CLOCK BAKELIKE GREEN, SKULL LUNCH BOX W...  0.010204
# 327089  (LUNCH BAG SPACEBOY DESIGN, ALARM CLOCK BAKELI...  0.010204
# 327087  (LUNCH BAG SPACEBOY DESIGN, ALARM CLOCK BAKELI...  0.010204
# 327086  (LUNCH BAG SPACEBOY DESIGN, PLASTERS IN TIN SP...  0.010204
# 327085  (LUNCH BAG SPACEBOY DESIGN, ALARM CLOCK BAKELI...  0.010204
# 327084  (LUNCH BAG SPACEBOY DESIGN, PLASTERS IN TIN SP...  0.010204
# 327164  (LUNCH BAG SPACEBOY DESIGN, ALARM CLOCK BAKELI...  0.010204
# 327163  (LUNCH BAG SPACEBOY DESIGN, ALARM CLOCK BAKELI...  0.010204
# 327162  (LUNCH BAG SPACEBOY DESIGN, ALARM CLOCK BAKELI...  0.010204
# 327183  (ALARM CLOCK BAKELIKE RED, ROUND SNACK BOXES S...  0.010204
#
#         confidence  lift
# 327102         1.0  98.0
# 327089         1.0  98.0
# 327087         1.0  98.0
# 327086         1.0  98.0
# 327085         1.0  98.0
# 327084         1.0  98.0
# 327164         1.0  98.0
# 327163         1.0  98.0
# 327162         1.0  98.0
# 327183         1.0  98.0
