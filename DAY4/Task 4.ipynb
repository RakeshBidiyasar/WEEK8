# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
df = pd.read_excel("Online Retail.xlsx")

#data cleaning
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

# sales for country FRANCE
france = (
    df[df['Country']== "France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')
    )

france

# encoding categories
france_encoded = (france > 0) 
france_encoded
frequent_itemsets = apriori(france_encoded, min_support=0.01, use_colnames=True)
frequent_itemsets
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)
top_rules = rules.sort_values(by='lift', ascending=False).head(10)
top_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
# Out:
#                                                antecedents  \
# 1349992  (DOLLY GIRL CHILDRENS CUP, ALARM CLOCK BAKELIK...
# 1350005  (SKULL LUNCH BOX WITH CUTLERY, LUNCH BOX I LOV...
# 1350006   (SKULL LUNCH BOX WITH CUTLERY, JUMBO BAG APPLES)
# 491832   (JUMBO BAG APPLES, ALARM CLOCK BAKELIKE PINK, ...
# 491828   (RED RETROSPOT MINI CASES, JUMBO BAG APPLES, A...
# 491827   (RED RETROSPOT MINI CASES, ALARM CLOCK BAKELIK...
# 491887   (LUNCH BAG APPLE DESIGN, ROUND SNACK BOXES SET...
# 984038   (LUNCH BAG APPLE DESIGN, ALARM CLOCK BAKELIKE ...
# 984035   (LUNCH BAG APPLE DESIGN, ROUND SNACK BOXES SET...
# 984066   (RED RETROSPOT MINI CASES, SKULL LUNCH BOX WIT...
#
#                                                consequents   support  \
# 1349992  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...  0.010204
# 1350005  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...  0.010204
# 1350006  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...  0.010204
# 491832   (RED RETROSPOT MINI CASES, ALARM CLOCK BAKELIK...  0.010204
# 491828   (LUNCH BAG APPLE DESIGN, ALARM CLOCK BAKELIKE ...  0.010204
# 491827   (LUNCH BAG APPLE DESIGN, JUMBO BAG APPLES, ALA...  0.010204
# 491887   (JUMBO BAG APPLES, ALARM CLOCK BAKELIKE GREEN,...  0.010204
# 984038   (RED RETROSPOT MINI CASES, SKULL LUNCH BOX WIT...  0.010204
# 984035   (RED RETROSPOT MINI CASES, SKULL LUNCH BOX WIT...  0.010204
# 984066   (ALARM CLOCK BAKELIKE RED, LUNCH BAG APPLE DES...  0.010204
#
#          confidence  lift
# 1349992         1.0  98.0
# 1350005         1.0  98.0
# 1350006         1.0  98.0
# 491832          1.0  98.0
# 491828          1.0  98.0
# 491827          1.0  98.0
# 491887          1.0  98.0
# 984038          1.0  98.0
# 984035          1.0  98.0
# 984066          1.0  98.0
